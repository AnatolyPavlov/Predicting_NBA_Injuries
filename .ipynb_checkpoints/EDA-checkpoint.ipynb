# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import rcParams
rcParams.update({'figure.autolayout': True})

# %matplotlib inline

# %%
injury_df = pd.read_csv('data/injuries.csv')
injury_df['REST'] = injury_df['Notes'].apply(lambda x: 1 if 'rest' in x or 'Rest' in x else 0)
injury_df['Date'] = pd.to_datetime(injury_df['Date'])
injury_df['YEAR'] = injury_df['Date'].apply(lambda x: x.year)
injury_df = injury_df[injury_df['YEAR'] > 0]

# %%
injury_rest = injury_df.groupby('YEAR').sum()

# %%
with plt.style.context('fivethirtyeight'):
    plt.figure(figsize=(14, 8))
    plt.plot(injury_rest.index, injury_rest['REST'], marker='o', c='b', alpha=.5)
    plt.xlabel('YEAR')
    plt.ylabel('GAMES MISSED (IN DAYS)')
    plt.suptitle('GAMES MISSED DUE TO REST PER SEASON', fontsize=20, y=1.05)    
    plt.tick_params(axis='both', which='major', labelsize=14)
    plt.xticks(np.arange(min(injury_rest.index), max(injury_rest.index)+1, 4.0), rotation='vertical')
    plt.savefig('images/dnp_rest.png', bbox_inches='tight')
